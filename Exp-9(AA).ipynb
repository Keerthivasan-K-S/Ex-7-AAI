# %%
nltk.download('punkt_tab')
nltk.download( 'punkt' )
nltk.download( 'stopwords' )

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import PorterStemmer

# %%
def preprocess_text(text):
	words = word_tokenize(text)
	stop_words= set(stopwords.words( 'english'))
	filtered_words= [word for word in words if word. lower() not in stop_words and word.isalnum()]
	stemmer = PorterStemmer()
	stemmed_words= [stemmer. stem(word) for word in filtered_words]
	return stemmed_words

# %%
def generate_summary(text,num_sentences=3):
	sentences= sent_tokenize(text)
	preprocessed_text = preprocess_text(text)
	word_frequencies =nltk. FreqDist (preprocessed_text)
	sentence_scores ={}
	for sentence in sentences:
		for word, freq in word_frequencies.items():
			if word in sentence.lower():
				if sentence not in sentence_scores:
					sentence_scores[sentence] = freq
				else:
					sentence_scores[sentence]+= freq
	summary_sentences= sorted(sentence_scores, key=sentence_scores.get,reverse=True) [ : num_sentences]
	return ' '. join(summary_sentences)

# %%
input_file="E:/Applied AI/Exp-9/TextFile.txt"
with open(input_file, 'r') as file:
	input_text = file.read()
summary = generate_summary(input_text)
print("Name: Keerthivasan K S\nReg no: 212224230120\n")
print("Origina1 Text: ")
print (input_text )
print( " \nSummary : " )
print(summary)
# Out:
# Name: Keerthivasan K S
# Reg no: 212224230120
#
# Origina1 Text:
# Natural Language Processing is a branch of artificial intelligence that focuses on the interaction between computers and humans using natural language. NLP enables computers to understand, interpret, and generate human language. It is used in many applications such as machine translation, sentiment analysis, chatbots, speech recognition, and text summarization.
#
# Text summarization is an important application of Natural Language Processing. It automatically produces a shorter version of a document while preserving its important information. There are different approaches to text summarization, including extractive and abstractive summarization. Extractive summarization selects important sentences directly from the original document, while abstractive summarization generates new sentences that represent the main ideas.
#
# Frequency-based summarization is a simple extractive summarization technique. It calculates the frequency of important words in a document and assigns scores to sentences based on the frequency of the words they contain. Sentences with higher scores are considered more important and are selected for the final summary.
#
# NLP techniques can help process large amounts of textual information efficiently. Text summarization is useful for news articles, research papers, reports, emails, and other documents where users need to quickly understand the main information.
#
# Summary :
# Extractive summarization selects important sentences directly from the original document, while abstractive summarization generates new sentences that represent the main ideas. Text summarization is useful for news articles, research papers, reports, emails, and other documents where users need to quickly understand the main information. Text summarization is an important application of Natural Language Processing.
